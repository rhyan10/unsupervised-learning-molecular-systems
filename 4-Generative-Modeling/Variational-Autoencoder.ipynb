# %% [markdown]
# # Variational Autoencoder
# In this notebook, we demonstrate the use of a variational autoencoder (VAE) to model and analyze a dataset of small molecules. VAEs are a type of generative model that can learn a compressed representation of data and generate new samples that resemble the training data. This makes them particularly useful for working with molecules, where understanding the underlying distribution and generating new molecular structures can be valuable tasks in molecular design.
#
# We will use a dataset of ~7K small molecules [../data/small_mols.csv](../data/small_mols.csv) to train our variational autoencoder.
#
# To run this notebook, you will need to use a kernel with the following libraries installed:
# * RDKit
# * Pandas
# * ipykernel

# %% [markdown]
# ## Building a model
# We will begin by defining a new model class called `MolecularVAE`:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data

class MolecularVAE(nn.Module):
    def __init__(self):
        super(MolecularVAE, self).__init__()

        # Define the layers used in the encoder
        self.conv_1 = nn.Conv1d(35, 20, kernel_size=5)
        self.conv_2 = nn.Conv1d(20, 15, kernel_size=5)
        self.conv_3 = nn.Conv1d(15, 9, kernel_size=5)
        self.linear_0 = nn.Linear(90, 100)
        self.linear_1 = nn.Linear(100, 100)
        self.linear_2 = nn.Linear(100, 100)

        # Define the layers used in the decoder
        self.linear_3 = nn.Linear(100, 100)
        self.gru = nn.GRU(100, 100, 3, batch_first=True)
        self.linear_4 = nn.Linear(100, 22)

        # Define activation functions
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()

    # Encoder function
    def encode(self, x):
        x = self.relu(self.conv_1(x))
        x = self.relu(self.conv_2(x))
        x = self.relu(self.conv_3(x))
        x = x.view(x.size(0), -1)
        x = F.selu(self.linear_0(x))
        return self.linear_1(x), self.linear_2(x)

    # Decoder function
    def decode(self, z):
        z = F.selu(self.linear_3(z))
        z = z.view(z.size(0), 1, z.size(-1)).repeat(1, 35, 1)
        output, hn = self.gru(z)
        out_reshape = output.contiguous().view(-1, output.size(-1))
        y0 = F.softmax(self.linear_4(out_reshape), dim=1)
        y = y0.contiguous().view(output.size(0), -1, y0.size(-1))
        return y

	# Sampling function for the latent space
    def sampling(self, z_mean, z_logvar):
        epsilon = 1e-2 * torch.randn_like(z_logvar)
        return torch.exp(0.5 * z_logvar) * epsilon + z_mean

    # Forward pass of the model
    def forward(self, x):
        z_mean, z_logvar = self.encode(x)
        z = self.sampling(z_mean, z_logvar)
        return self.decode(z), z_mean, z_logvar

# %% [markdown]
# We also need to define a function for encoding SMILES string as one-hot vectors, and a loss function. Here, we will use the binary cross-entropy (BCE) loss.

# %%
import numpy as np

# Function to convert SMILES strings to one-hot encodings
def smiles_to_hot(smiles, max_len, char_indices, nchars):
    X = np.zeros((len(smiles), max_len, nchars), dtype=np.float32)
    for i, smile in enumerate(smiles):
        for t, char in enumerate(smile):
            X[i, t, char_indices[char]] = 1
    return X

# Function to calculate the VAE loss using the BCE
def vae_loss(x_decoded_mean, x, z_mean, z_logvar):
    xent_loss = F.binary_cross_entropy(x_decoded_mean, x, size_average=False)
    kl_loss = -0.5 * torch.sum(1 + z_logvar - z_mean.pow(2) - z_logvar.exp())
    return xent_loss + kl_loss

# %% [markdown]
# ## Preparing the data

# %%
# Preprocess the SMILES strings
all_chars = []
max_len = 35

file_path = '../data/smiles.txt'
smiles_strings = []
with open(file_path, "r") as file:
    smiles_strings_with_newlines = file.readlines()
    smiles_strings = [smi[:-1] for smi in smiles_strings_with_newlines]

for smi in smiles_strings:
    characters = [char for char in smi]
    all_chars.append(characters)

# Define the character indices for one-hot encoding
char_indices = {'S':0, '2':1, 'O':2, '[':3, 'o':4, '\\':5, 'c':6, '3':7, 'C':8, ')':9, 's':10, 'N':11, '(':12, 'H':13, ']':14, '#':15, 'n':16, '1':17, '@':18, '/':19, '=':20, ' ':21}

# Convert SMILES strings to one-hot encodings
one_hot_embeddings = smiles_to_hot(all_chars, max_len, char_indices, 22)
print(one_hot_embeddings.shape)

# Split the data into train and test datasets
data_train = one_hot_embeddings[:6000]
smiles_train = smiles_strings[:6000]
data_train = torch.utils.data.TensorDataset(torch.from_numpy(data_train))

data_test = one_hot_embeddings[6000:]
smiles_test = smiles_strings[6000:]
data_test = torch.utils.data.TensorDataset(torch.from_numpy(data_test))
# Out:
# (7165, 35, 22)

# %% [markdown]
# ## Training the model
# Below we will train the VAE for 30 training epochs using a batch size of 50 and an initial learning rate of 0.001, with a cosine learning rate scheduler.
#
# Depending on your computer, this may take about 10 minutes or so. If you don't want to wait that long, reduce the number of training epochs and continue with the analysis; the model may not be as good in that case, but you should still be able to get some insights.

# %%
import torch.optim as optim

# Define training parameters
batch_size = 50
num_epochs = 30
init_lr = 0.001

# Create a dataloader for the train split
train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size, shuffle=True)

# Create an instance of the MolecularVAE model
model = MolecularVAE()

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=init_lr)

train_losses = []  # For storing the train loss per epoch
test_losses = []  # For storing the test loss per epoch

# Training loop
for epoch in range(num_epochs):
    model.train()
    train_loss = 0

    for batch_idx, data in enumerate(train_loader):
        data = data[0]

        optimizer.zero_grad()   # Zero the gradients at the start of each mini-batch

        output, mean, logvar = model(data)
        loss = vae_loss(output, data, mean, logvar)

        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # Store the training loss after each epoch
    train_losses.append(train_loss / len(train_loader.dataset))

    # Save the model after each epoch
    file_path = "VAEmodel.pth"
    torch.save(model.state_dict(), file_path)

    # Compute and store the test loss after each epoch
    model.eval()
    with torch.no_grad():
        output_test, mean_test, logvar_test = model(data_test[:][0])
        test_loss = vae_loss(output_test, data_test[:][0], mean_test, logvar_test)
        test_losses.append(test_loss.item() / len(data_test))

    # Print progress
    lr = scheduler.get_lr()[0]
    print(f'Epoch {epoch}  Learning Rate: {lr:3e}  Train Loss: {train_losses[-1]:3f}  Test Loss: {test_losses[-1]:3f}')
# Out:
# Epoch 0  Learning Rate: 6.968044e-04  Train Loss: 67.470277  Test Loss: 69.260093
# Epoch 1  Learning Rate: 6.968044e-04  Train Loss: 61.905868  Test Loss: 64.378246
# Epoch 2  Learning Rate: 6.968044e-04  Train Loss: 57.913309  Test Loss: 62.473122
# Epoch 3  Learning Rate: 6.968044e-04  Train Loss: 56.495758  Test Loss: 62.455076
# Epoch 4  Learning Rate: 6.968044e-04  Train Loss: 55.360027  Test Loss: 60.693951
# Epoch 5  Learning Rate: 6.968044e-04  Train Loss: 53.746745  Test Loss: 59.225268
# Epoch 6  Learning Rate: 6.968044e-04  Train Loss: 52.666607  Test Loss: 58.280995
# Epoch 7  Learning Rate: 6.968044e-04  Train Loss: 51.939837  Test Loss: 57.641470
# Epoch 8  Learning Rate: 6.968044e-04  Train Loss: 51.103224  Test Loss: 57.124363
# Epoch 9  Learning Rate: 6.968044e-04  Train Loss: 50.499069  Test Loss: 56.339304
# Epoch 10  Learning Rate: 6.968044e-04  Train Loss: 50.297145  Test Loss: 56.541208
# Epoch 11  Learning Rate: 6.968044e-04  Train Loss: 49.572830  Test Loss: 55.823260
# Epoch 12  Learning Rate: 6.968044e-04  Train Loss: 48.818726  Test Loss: 54.727374
# Epoch 13  Learning Rate: 6.968044e-04  Train Loss: 49.157122  Test Loss: 54.977552
# Epoch 14  Learning Rate: 6.968044e-04  Train Loss: 48.140933  Test Loss: 55.530707
# Epoch 15  Learning Rate: 6.968044e-04  Train Loss: 47.892749  Test Loss: 55.019236
# Epoch 16  Learning Rate: 6.968044e-04  Train Loss: 48.169794  Test Loss: 54.389344
# Epoch 17  Learning Rate: 6.968044e-04  Train Loss: 47.663558  Test Loss: 54.476784
# Epoch 18  Learning Rate: 6.968044e-04  Train Loss: 46.627200  Test Loss: 53.338077
# Epoch 19  Learning Rate: 6.968044e-04  Train Loss: 46.689322  Test Loss: 53.616574
# Epoch 20  Learning Rate: 6.968044e-04  Train Loss: 46.839615  Test Loss: 52.444907
# Epoch 21  Learning Rate: 6.968044e-04  Train Loss: 45.705613  Test Loss: 52.595266
# Epoch 22  Learning Rate: 6.968044e-04  Train Loss: 46.343828  Test Loss: 52.630080
# Epoch 23  Learning Rate: 6.968044e-04  Train Loss: 46.004545  Test Loss: 54.730817
# Epoch 24  Learning Rate: 6.968044e-04  Train Loss: 45.144927  Test Loss: 51.474567
# Epoch 25  Learning Rate: 6.968044e-04  Train Loss: 45.420448  Test Loss: 53.399852
# Epoch 26  Learning Rate: 6.968044e-04  Train Loss: 45.102921  Test Loss: 52.031558
# Epoch 27  Learning Rate: 6.968044e-04  Train Loss: 44.777061  Test Loss: 52.082652
# Epoch 28  Learning Rate: 6.968044e-04  Train Loss: 44.678753  Test Loss: 51.563593
# Epoch 29  Learning Rate: 6.968044e-04  Train Loss: 43.942623  Test Loss: 51.735186

# %% [markdown]
# ## Analysis and best practices
# Let's begin by visualizing the loss curves:

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(4, 3))

ax = fig.add_subplot(1, 1, 1)

# Plot the loss as a function of the number of training epochs
ax.plot(train_losses, color='blue', lw=1, label='Train loss')
ax.plot(test_losses, color='red', lw=1, label='Test loss')
ax.set_xlabel('Epoch', size=10)
ax.set_ylabel('Loss Curves', size=10)
ax.legend(fontsize=10)
ax.tick_params(axis='both', which='major', labelsize=10)
plt.tight_layout()

# %% [markdown]
# ### SMILES reconstruction
# Next, let's analyze how well our model can reconstruct SMILES strings from the test set.
#
# First, we will compute the reconstruction loss for the test set and compare to the training set.

# %%
# Create a dataloader for the test split
test_loader = torch.utils.data.DataLoader(data_test, batch_size=batch_size, shuffle=True)

# Calculate reconstruction loss on test data and compare to train data
model.eval()
with torch.no_grad():
    test_loss = 0
    for batch_idx, data in enumerate(test_loader):
        data = data[0]

        output, mean, logvar = model(data)
        loss = vae_loss(output, data, mean, logvar)

        test_loss += loss.item()

print(f'Train loss after {epoch + 1} training epochs: {train_loss / len(train_loader.dataset):.3f}')
print(f'Test loss after {epoch + 1} training epochs: {test_loss / len(test_loader.dataset):.3f}')
# Out:
# /Users/rocom/opt/anaconda3/envs/nb1-env/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Train loss after 30 training epochs: 43.943
# Test loss after 30 training epochs: 51.823

# %% [markdown]
# The model appears to be a little overfit, but that should not be a huge issue here.
#
#
# To see what the SMILES look like, we will define a function for 'decoding' the VAE output embeddings into SMILES, and look at a few SMILES from the training and test sets in detail to see how good the model is at reconstructing them.

# %%
# Uncomment this box to load a previously-trained model and continue with the analysis below

# # Create an instance of the MolecularVAE model
# model = MolecularVAE()
#
# # Load the state dictionary from the .pth file
# model_path = 'VAEmodel.pth'
# state_dict = torch.load(model_path)
#
# # Load the state dictionary into the model
# model.load_state_dict(state_dict)

# %%
# Define a function to convert VAE output embeddings 'back' to SMILES strings
def emb_to_smiles(embedding, indices_char):
    smiles = []
    for one_hot in embedding:
        smiles_chars = []
        for vector in one_hot:
            if int(torch.sum(vector)) == 0:
                continue  # Skip padding
            char_index = int(torch.argmax(vector))
            char = indices_char[char_index]
            smiles_chars.append(char)
        smiles.append(''.join(smiles_chars).strip())
    return smiles

# Define the character indices for one-hot encoding
indices_char = {v: k for k, v in char_indices.items()}
print(indices_char)
# Out:
# {0: 'S', 1: '2', 2: 'O', 3: '[', 4: 'o', 5: '\\', 6: 'c', 7: '3', 8: 'C', 9: ')', 10: 's', 11: 'N', 12: '(', 13: 'H', 14: ']', 15: '#', 16: 'n', 17: '1', 18: '@', 19: '/', 20: '=', 21: ' '}

# %%
# Let's visualize the reconstructions for the first five training and test set SMILES
model.eval()
with torch.no_grad():
    train_embeddings, _, _ = model(data_train[:5][0])
    test_embeddings, _, _ = model(data_test[:5][0])

# Decode the one-hot encoded SMILES to see how they are deconstructed
decoded_train_smiles = emb_to_smiles(train_embeddings, indices_char)
print('Training set SMILES reconstruction:')
for i, smiles in enumerate(decoded_train_smiles):
	print(f'True: {smiles_train[i]}  Reconstructed: {smiles}')

print(' ')

decoded_test_smiles = emb_to_smiles(test_embeddings, indices_char)
print('Testing set SMILES reconstruction:')
for i, smiles in enumerate(decoded_test_smiles):
	print(f'True: {smiles_test[i]}  Reconstructed: {smiles}')
# Out:
# Training set SMILES reconstruction:
# True: C  Reconstructed: ]C[]]121]===========
# True: CC  Reconstructed: CC(=[N]C[HH]11]]111111111
# True: C=C  Reconstructed: C1C=[NC]]11]111111111
# True: C#C  Reconstructed: CC1CC@HO111]]nnnn===
# True: CCO  Reconstructed: CCC(=NCH]1111]11111111
#
# Testing set SMILES reconstruction:
# True: O[C@H]1C=CNC1=O  Reconstructed: CH]CCC=))1@]]1]==========
# True: O[C@H]1CCNC1=O  Reconstructed: CCH1CCC=O11]11OOOOOOOO
# True: OC1=CC=[N]=C[CH]1  Reconstructed: C1CCCH]C]]]11111========
# True: OC1CCNCC1  Reconstructed: CCCCCC1111]nnnnnnnnnnno
# True: C[C@H]1CCCN1C  Reconstructed: @C=O)111]SSSSSSSSS

# %% [markdown]
# The reconstructed SMILES will probably not look that great because the model is not fully converged. Nevertheless, we can still gain other insights from the model.
#
# 💡 Note that as the model is a VAE, the reconstructed SMILES may look different each time, especially if the model is not converged.

# %% [markdown]
# ### Latent space visualization
# We can also explore the latent space between two molecules by interpolating between their latent vectors.
#
# Let's start by visualizing the latent space using PCA, as in the [Dimensionality Reduction](../2-Dimensionality-Reduction/Dimensionality-Reduction.ipynb) notebook.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

_, z_mean, z_logvar = model(data_train[:][0])

latent_space = z_mean.detach().numpy()

# Apply PCA for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(latent_space)

# Plot the latent space and color points according to SMILES length
plt.figure(figsize=(4,3))
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5, c=[len(smiles) for smiles in smiles_train])
plt.colorbar(label='SMILES length')
#plt.title('Latent Space Visualization (PCA)', size=10)
plt.xlabel('PC 1', size=10)
plt.ylabel('PC 2', size=10)
plt.tight_layout()

# %%
# Let's color the PCA according to an interesting physicochemical property
from rdkit import Chem
from rdkit.Chem import Descriptors

property = []
for smi in smiles_train:
        mol = Chem.MolFromSmiles(smi)
        try:
            property.append(Descriptors.NumAromaticRings(mol))
        except:
            property.append(-1)

# Plot the latent space and color points according to SMILES length
plt.figure(figsize=(4,3))
plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5, c=property)
plt.colorbar(label='Number of aromatic rings')
plt.title('Latent Space Visualization (PCA)', size=10)
plt.xlabel('PC 1', size=10)
plt.ylabel('PC 2', size=10)
plt.tight_layout()

# %% [markdown]
# ### Latent space interpolation
# Now, let's try interpolating between two points in the latent space of our VAE.
#
# 💡 Note that the latent space learned by a VAE is typically not linear, but rather a non-linear manifold embedded in a higher-dimensional space. This means that linear interpolation between two points in the latent space may traverse regions that do not necessarily correspond to valid data points. For more meaningful interpolations, try spherical linear interpolation (Slerp) instead of linear interpolations.

# %%
# Define a spherical linear interpolation function; `midpoint` ranges from 0 (closer to `p1`) to 1 (closer to `p2`)
def slerp(p1, p2, n_inbetween_points=10):
    p1, p2 = torch.tensor(p1), torch.tensor(p2)
    interpolations = []
    for midpoint in np.linspace(0, 1, num=n_inbetween_points):
        omega = torch.acos(torch.clamp(torch.dot(p1 / torch.norm(p1), p2 / torch.norm(p2)), -1, 1))
        so = torch.sin(omega)
        if so == 0:
            interpolations.append((1.0 - midpoint) * p1 + midpoint * p2)  # L'Hopital's rule/LERP
            continue  # Avoid appending twice in case of L'Hopital's rule
        interpolations.append(torch.sin((1.0 - midpoint) * omega) / so * p1 + torch.sin(midpoint * omega) / so * p2)
    return torch.stack(interpolations)

# If you are curious about the differences between linear and Slerp interpolation, try
# interpolating with the function below instead of the slerp function
def linear_interpolation(point1, point2, n_inbetween_points=10):
    point1, point2 = torch.tensor(point1), torch.tensor(point2)
    ratios = np.linspace(0, 1, num=n_inbetween_points)
    vectors = [(1.0 - ratio) * point1 + ratio * point2 for ratio in ratios]
    return torch.stack(vectors)

# %%
# Select two random points in the latent space
idx1 = 54  # Can be between 0 and 5997 (i.e., 6000 minus 3)
idx2 = 77  # Can be between 0 and 5997 (i.e., 6000 minus 3)

smiles1 = smiles_train[idx1]
smiles2 = smiles_train[idx2]

point1 = latent_space[idx1]
point2 = latent_space[idx2]

# Generate interpolations
interpolations = slerp(point1, point2)
#interpolations = linear_interpolation(point1, point2)

# Decode the interpolations
model.eval()
with torch.no_grad():
    decoded_interpolations = model.decode(interpolations)

# Print the SMILES corresponding to the interpolated values after decoding
print(f'Point 1: {smiles1}')
decoded_smiles = emb_to_smiles(decoded_interpolations, indices_char)
for i, smiles in enumerate(decoded_smiles):
    print(f'- Interpolation {i}: {smiles}')
print(f'Point 2: {smiles2}')
# Out:
# Point 1: C=CC=C
# - Interpolation 0: CCCCCC11nnnSSS](((((
# - Interpolation 1: CCCCCCO11nnnnnSS]]]((((((
# - Interpolation 2: CCCCCCN1nnnSSSS]]]](((((
# - Interpolation 3: CCCC1111SSSSS]]]((((
# - Interpolation 4: CCCN11222]]]](((((((
# - Interpolation 5: CCCC111]]]]]]]]]]((((
# - Interpolation 6: CCCCCCC111]]]]]]]]]]](((((
# - Interpolation 7: CC1CCCC111]]]]]]]]]](((
# - Interpolation 8: CC1C1CO]]]]]]]]]]]===
# - Interpolation 9: CCCC11111]]]]]]]]]]====
# Point 2: OC1CCC1

# %% [markdown]
# ### SMILES generation
# Finally, we will evaluate how well our VAE works in generating new molecules.
#
# This can be done a number of ways. Below we will demonstrate two approaches, one worse and one better:
# * Generating random latent vectors and decoding
# * Sampling from the latent space and decoding

# %% [markdown]
# #### Decoding random points in the VAE latent space

# %%
num_samples = 500

# Generate random latent vectors
random_vectors = torch.randn(num_samples, len(latent_space[0]))

model.eval()
with torch.no_grad():
    generated_samples = model.decode(random_vectors)

# Print the SMILES corresponding to the random latent vectors after decoding
print(f'Random latent vectors decode to:')
generated_smiles = emb_to_smiles(generated_samples, indices_char)
for i, smiles in enumerate(generated_smiles):
    print(f'- Sample {i}: {smiles}')
# Out:
# Random latent vectors decode to:
# - Sample 0: C1=C[H]O[@@]1O1]]]]]]]]
# - Sample 1: CCCCC((/)C)C]]]]]]]]]]]]]]
# - Sample 2: 1CCCC11111nnnnnnnnnnn111
# - Sample 3: C####@@@@@@@@@@@@@@@@@@@@
# - Sample 4: CCC[]][C@HH[@H]([@HH]
# - Sample 5: CCCCCCCC//////////////
# - Sample 6: NNSSSSSSSSSSSSSSSSSSSSSSS
# - Sample 7: CCC1111nnnnnnnnnnoo
# - Sample 8: C=CCCCCC1CCC))@@@@\\\\\\
# - Sample 9: C[C]]CC11@H]1111122111111111
# - Sample 10: N[[[nnnSSSSSSSSSSSSSSSSSS
# - Sample 11: CCC=N=N][[1111]]N===[[
# - Sample 12: =/C))))))))))))))))))))
# - Sample 13: Cccnccccccccccccccccc
# - Sample 14: CN=CCC]]2============///
# - Sample 15: [C@]C@HO==////////////
# - Sample 16: C==))//////////////////
# - Sample 17: CC=CC=CCC////////////
# - Sample 18: ]]////////////////))
# - Sample 19: C@22@H1C1CC233CCCCCCCCCC
# - Sample 20: C#C#C#######///////////////
# - Sample 21: Cc1cccH])c[H1111111111HHHH
# - Sample 22: [CH]C11222213333
# - Sample 23: C[H][C])CCC////////////////
# - Sample 24: C[@1CCC11111111111111
# - Sample 25: C=CCCC@2NCcccccccccnnccccc
# - Sample 26: CNCCCCC1]1111]]]]11111111111
# - Sample 27: CCCC@@]12222233333333333333
# - Sample 28: Cc1ccc11111111111
# - Sample 29: CCC1CCC==                 s
# - Sample 30: Ccnnnn[[[[[[[[[[
# - Sample 31: Cc1cn(ccncccccccccccccHcccH
# - Sample 32: ###########################
# - Sample 33: 1ccccccccccccccccccccc
# - Sample 34: C[@H])C]N)C]C)CCCCCCC
# - Sample 35: C@@H]2())]22)]]]2]]]]]]]]
# - Sample 36: CCC1CCC=CCCCCCCCC     CCO
# - Sample 37: Cccccc11111111ccccccccc
# - Sample 38: C(///CC(]////////
# - Sample 39: CCCCCC=##NNNCCCCCCC
# - Sample 40: C[]]N)CC)////////////
# - Sample 41: Ccn(]nH))))))))))))HH
# - Sample 42: C[][N][NH[][[[[]]))CCCCCCC
# - Sample 43: CCCCC==#######CCCCCCC
# - Sample 44: C[C]N=[N][H][]]]]]]]1C[[
# - Sample 45: [C@]CCCC@]NCH]H]]CH]]]CC
# - Sample 46: CC][C@333333333333
# - Sample 47: CCCC[[CH(OCH]]C]]]]]]]]
# - Sample 48: CCC[C11C)C11]]]][[[[[[[[[[[[
# - Sample 49: C=[C@H]2C@@H2]]22333
# - Sample 50: CH]1[C@C[@]122]2222222
# - Sample 51: O#CCCC11H]12233333333333333333
# - Sample 52: =C@@CCC2333333333333333
# - Sample 53: C]11C@]O)CHH1OOOOO))))))
# - Sample 54: CC=CCCCnnnnnnnnnnooo1111
# - Sample 55: CCCCCCCCCCCCCCC)))))))))]
# - Sample 56: C@]CH]2C[C@H]]C2@3323[[[
# - Sample 57: C(=///CCCC///////////////
# - Sample 58: cccccccccccccccccccccccccc
# - Sample 59: CCCCCCCCCC/#####==CCCCCCCC
# - Sample 60: C#CC@H222222233333333[[nnn
# - Sample 61: CC[C@H][C@C@@]]2212][[[[
# - Sample 62: C/nnnnnnnncccccccccccccccccc
# - Sample 63: CCCC11]222222222222222
# - Sample 64: C@@H]1C[C@][C@@H]232\
# - Sample 65: C/C=C/[C@H]()CCC]]]]]]]]]]]]]]
# - Sample 66: C=CCCC#C#=#################
# - Sample 67: 1cccccccc1111111111HHHHH
# - Sample 68: ][CH[[CHC111]CCC[[[[[[
# - Sample 69: C(CCCCCC)CCCCCCC////////////
# - Sample 70: C/C/CCCCC///###CCCCC
# - Sample 71: Cc1ccccccccccccccccccc
# - Sample 72: Cc1ccc1111cccccc))))
# - Sample 73: CNH][@]CC)O))=============
# - Sample 74: CCCCC=/CCCCCCCCCCCCCCCC
# - Sample 75: @
# - Sample 76: [[@@H]1[@H]2C[C@H]2C@H32OOO
# - Sample 77: CC@@H](C)CCCCC11111OOO[[[[[[
# - Sample 78: CCCC@]1@]]]]]]]N======##
# - Sample 79: C=C///C/C###############
# - Sample 80: [C@CCC@H2111ooooooooooo
# - Sample 81: SSSSSSSSSSSSSSSSSSSSS
# - Sample 82: c2cccc[[[ccccccccccccc
# - Sample 83: CCC=CC1111111nnnn==========
# - Sample 84: Nccc@cccccccccccccc
# - Sample 85: ##
# - Sample 86: 1[CC][C[][]]]]]][[@H]]11
# - Sample 87: C(=//C///////////////////
# - Sample 88: C[C@@H]2[@@H]1C[@H]1CC@H]2C[@@
# - Sample 89: #CCCCCC11333333333333333
# - Sample 90: ]H
# - Sample 91: CC@]1(CC)C1111111111111111
# - Sample 92: C1C[[CH[[[]H[[[[]111[
# - Sample 93: #CCC11H]] sssssssssssssss
# - Sample 94: CCCCC)CCCCCC////////////////
# - Sample 95: C]C]C][CHH][]]CC@H]CCC
# - Sample 96: CCH]1[C@@H]2C)[CH]2C[C\\\
# - Sample 97: ccccccccccSSSSSSooooo
# - Sample 98: CCCCCH]22222222333333333
# - Sample 99: C/C/C/C/CCCCCC//////
# - Sample 100: /C==(=(/==//O//NNNNNN
# - Sample 101: (//H]()))/))))))))
# - Sample 102: ################################
# - Sample 103: C@H1CC]2[@@H2222CC
# - Sample 104: c111222222222222222222222
# - Sample 105: OC@@111111ssssssssssss
# - Sample 106: CCccccccccccccccccccccccccc
# - Sample 107: ccccc@H]CCC@@H]22
# - Sample 108: CC]/=[NH]CCCCCC]]O[[[[[[
# - Sample 109: C=#CC##3###############
# - Sample 110: CC[[C@H]]OC@@H]121Cnnnnnnn
# - Sample 111: [CC[CC1111]]]]]]]]]nnnnnnnnn
# - Sample 112: ccccccccccccccccccccccc
# - Sample 113: CC((=)CCC///////////////
# - Sample 114: Cc1cccc111111111c))))))))
# - Sample 115: 1[C@@H]2C@@H2[[@2H]]]]]
# - Sample 116: [HH/(=/N=NNNNNNN))CCCC]]]
# - Sample 117: H]22C[@H2C223CCCCCCCCC
# - Sample 118: [C@([C]H]])))((()
# - Sample 119: Ccccccccc1111HHHHHHHHHHHHH
# - Sample 120: Cnncccccccccccccccc
# - Sample 121: C[@H1CCH]1CC@@2111111111
# - Sample 122: CC@]]]]H][]]]]CCCCCOOO
# - Sample 123: CC((CCCC11nnn11111111111
# - Sample 124: C[C@]1CC@@H12C@33333333333
# - Sample 125: Cccnn]cc)c]]11]]11111
# - Sample 126: [[ccc@@@@@@@@@@@@@@@@@@@
# - Sample 127: ###nnnnnnnnnnnnnnnnnnnn
# - Sample 128: C@1CH]2CC)[@HOOOOOO
# - Sample 129: CCC11H11111nnnnnnnnnnnnn
# - Sample 130: #CCC12H3333333333333333333
# - Sample 131: CCC/C/CC//////##########
# - Sample 132: CC1CCCCC1111nnnnnnn11111
# - Sample 133: C1cc111111111111111
# - Sample 134: O############################
# - Sample 135: C=C/C/CC###################
# - Sample 136: /=////////////////////
# - Sample 137: CC=CCCCCCCCCCCCCCCCCC
# - Sample 138: C@H11@H11oooooooooo
# - Sample 139: CC@@[@H]([HH](C)@HHCCC
# - Sample 140: CC2][NNCCCC]]=======
# - Sample 141: CC=/CCCCCCC////////////
# - Sample 142: CCCCCCCC==///######////////
# - Sample 143: CC@]1(C)@H(OC22]])))))
# - Sample 144: CCH]CCC111111111111111
# - Sample 145: Cc1ccccccccccccccccccccc
# - Sample 146: =C(C))///////////NNNN
# - Sample 147: C@@]]@]2[CH]CCC@@H1O
# - Sample 148: C(CCCCCC///////////CC
# - Sample 149: @@H(C=C))))////////
# - Sample 150: Cc1ccccccccccccccccccc
# - Sample 151: [H1@@@@@@nnnnnnnnnnn
# - Sample 152: Ccccccccccccccccccccc11
# - Sample 153: CCC(=))////////////////
# - Sample 154: ((((((((((((((((((((((((((
# - Sample 155: CNCCCC1111111111111111
# - Sample 156: C#CCCCCCCCC//CC#####///////
# - Sample 157: CC=NN=C[H]]11111111111
# - Sample 158: CC(=)CCCC2222222111/////
# - Sample 159: OCC112ssssssssssssssssssssss
# - Sample 160: CCCCCCCCC///////////
# - Sample 161: CC1CC1=CCCCCCCCCCCCCOOOO
# - Sample 162: Cc1cccccccccccccc11111111111
# - Sample 163: C=CC)[[[[[[CCC[]]]][[
# - Sample 164: CC]C]N=[[[]]]]]H]]]]]]]]
# - Sample 165: C1[@]2[C@H]C[@2C@@H22CC
# - Sample 166: CC)][[[]][]H]]2]]]]]]
# - Sample 167: C[CH]1C[C@H12@@33333333333
# - Sample 168: C[[[H][[][H]H]HH]]]
# - Sample 169: Cnncccccccccccccccc
# - Sample 170: C[C@H]2[C@]]1C[C@H]1CC@H2[[
# - Sample 171: //nnnnnnnncccccccccc
# - Sample 172: CC(=CCC111nnnnnnnnnnnnnnnn
# - Sample 173: CC[[N][CC[C1111111111111
# - Sample 174: C[@@](OCCCCCC]]]))))))))
# - Sample 175: N[C@]11@@nnnnnnnnnnnnnnnnn
# - Sample 176: [HH]]C]CN][NH[H]]]]]H]]]]]]]
# - Sample 177: /CC==//C///////////
# - Sample 178: ==========################
# - Sample 179: cC@@H]ccccccccccccccccccccc
# - Sample 180: C[]C[H]CCCCCCCOO[[
# - Sample 181: CCCC@H]1C@333333333333333
# - Sample 182: C=/nnnnnnnnnnnnnnnnnnnn
# - Sample 183: CCC=///C/CCCC///////CC
# - Sample 184: #C=###////////////////////////
# - Sample 185: CCCC11nnnnnnnnn2222222
# - Sample 186: C[C]]H][C]H][]H]]]]]]]]]
# - Sample 187: nnnnn
# - Sample 188: C[C@H]C11@1111ooooooooooo
# - Sample 189: C[][C]CC1111111111111111
# - Sample 190: C]1[]](O)CCCH]OOO)))))
# - Sample 191: C()CCC===CC==CCCCCCCCC
# - Sample 192: C[C@@H1[C@]2C[@]2C@@HC[CC
# - Sample 193: C[C@H](@]CC@@H(C)C@])C
# - Sample 194: CC((=C=)C////==========
# - Sample 195: C#/C/CCCCCC11cccccccc
# - Sample 196: CCCCCCCCCCCOC==nnnnnnnnnnn
# - Sample 197: [[H11CCCSSSSSSSSSSSSS
# - Sample 198: 1CCC1111111[[[[[[[[[[[
# - Sample 199: #C@@22222222222222222
# - Sample 200: =C[CH]C[@@HCC33333333333
# - Sample 201: C#############ccccccccccccc
# - Sample 202: CCCCCCCCC==/////////////
# - Sample 203: C[@@]][C@@H]())C@O)C@CCC
# - Sample 204: N=cccccccccccccccccccc
# - Sample 205: [@Hcc]]cccccccccccc
# - Sample 206: [C@H]2CH]2CC@HH][[222[[
# - Sample 207: C//=//////////////
# - Sample 208: C][H][@@H111111111111111
# - Sample 209: #########################
# - Sample 210: C=C=///////////////////
# - Sample 211: CCCCCCCC=CCCCCCCCCCCCCCCC
# - Sample 212: [ccccccSSSSSSSSSSSSSS
# - Sample 213: C[C@]1CH]CCC[C@]12SSS
# - Sample 214: C[1[@][H]2C[22H]22[[
# - Sample 215: CCHNCCC12]==========
# - Sample 216: C#########################
# - Sample 217: (((ccccccccccccccccc
# - Sample 218: @@]1C@H]2C@@2CCCCCCCC
# - Sample 219: ccc1111cccccccccccccc
# - Sample 220: CH2]CCCCC111]]1111111111
# - Sample 221: Cc)c11111111111oooo
# - Sample 222: ccccccccccccccccccccc
# - Sample 223: C[@C[C@H]1C2222122221112222
# - Sample 224: CCCC(/[[[[N[[[][[H]]]
# - Sample 225: CCCCCC2Cc[[[c1111111111
# - Sample 226: CCCNNNNNCC111111111
# - Sample 227: CCCCCCCCCCCCCCCCCCC#####
# - Sample 228: C[]/C==H])CCCC]]]]]]]]]
# - Sample 229: C[C@C[C@H122233333333333
# - Sample 230: C#C#######################
# - Sample 231: =1nnnnnnnnnnnnnnnnnnnnnnn
# - Sample 232: C###((((((((((((((((((
# - Sample 233: OCCC#######22#########33
# - Sample 234: C[C][](O)C11C]]))))))))
# - Sample 235: CCCCC11sssssssssssssss
# - Sample 236: cccccc11111111111HHHH
# - Sample 237: C(=)CCCC11111111111111111
# - Sample 238: C())CCC//CCCCCCCCCCCC
# - Sample 239: CH]1[C@H]2[[@H11222\\\
# - Sample 240: C[C]][H]))=)]C]]/////////
# - Sample 241: O#CCC11223333333ssss
# - Sample 242: @H1C@CC[C@]1OSSSSSSS
# - Sample 243: C[H]1[C@H1OoOOOOOOOOO
# - Sample 244: ccnnnnnnnnnnnnnnnnn
# - Sample 245: C[C@@[@@()C@H]()C@@]1C1C
# - Sample 246: C[C][CHNC=)CCC]]]////////
# - Sample 247: C[C])C1111[[[[oooooooo
# - Sample 248: C[H][CH]1CC[@H2Cooooooo
# - Sample 249: C#C1nnnccccccccccccccccccc
# - Sample 250: #########################
# - Sample 251: CCCCCC1=1CnnnnnnnnnnOO
# - Sample 252: #CCCCC=22            ssss
# - Sample 253: CCCC)CCCC=))))))((
# - Sample 254: ccc1111
# - Sample 255: C)=CCCCCCC//////////
# - Sample 256: [CC@H]C[@H]2@3333333
# - Sample 257: CCCCCCCCCCCCCCCCCCCCCCCCCC//
# - Sample 258: CC]]N]H][C]]CCCCCCCCC
# - Sample 259: C][C]C111111[[[[[[
# - Sample 260: C==///C/CC//////CCCC
# - Sample 261: CC][C]]CC11111211[[[)))
# - Sample 262: CCCCC=1nnnnnnnnnnnn
# - Sample 263: O#CCC11O2333333333333
# - Sample 264: C1cccccccccccccccccc
# - Sample 265: Cccccc111111cccccccccccccc
# - Sample 266: #CCCC11     ssssssssssss
# - Sample 267: C/C===C(/(/)))/CCC]]]]]]]]]
# - Sample 268: CN[CH1]]]]]]111111
# - Sample 269: [C@]1O[C@H(O))C111111]]]]]]N
# - Sample 270: C(CCCCCCC===========n))(
# - Sample 271: C@])[H[CC222]\\\\\\\\
# - Sample 272: C[CC11111111111oo
# - Sample 273: NOCCCC####=================
# - Sample 274: 1CCCCCCCSSSSSSSS
# - Sample 275: C[C@1[C@H]2CH]2CCC@H]2OOOO
# - Sample 276: C=C[H(OCCH]]]]]]]OOO
# - Sample 277: C(CC)CCCC///////////
# - Sample 278: C#=/////////////////
# - Sample 279: @
# - Sample 280: CCCCCCC==####CCCCCCCC
# - Sample 281: C1ccc1111ccHHHHHHHHHHH
# - Sample 282: CCC[CC@2[C@@H]22111]2[[[[[[
# - Sample 283: N/////////))///////////
# - Sample 284: C[H]C[C@H](C)[C@H]1111OOO
# - Sample 285: CC]1(O)CCCCC]/////////////
# - Sample 286: C[@]1[@@H]2CCH]221213
# - Sample 287: ############################
# - Sample 288: c1))))))))))))))))))))
# - Sample 289: C[@]1CCC=C111121111]]]]]]
# - Sample 290: C/=/C//////////////////
# - Sample 291: CC@]1CC](C1((((((SSSS))
# - Sample 292: [][]N)=)CCCO]]]////////////
# - Sample 293: C##C#####################
# - Sample 294: @@      22222222222222222222
# - Sample 295: C[C[H]CCCCCC111OOO[[[[[[[
# - Sample 296: 1cccccccccccccc111111
# - Sample 297: /C=//)))H]]]]]]]]]]]]//
# - Sample 298: NC@H1[CH]2OOooooooooSSSSS
# - Sample 299: CCC]]CH[C][][[H]H]]HH]]]C
# - Sample 300: C1111#
# - Sample 301: CH2]/(==///N)CCCCC]]]]]]]
# - Sample 302: C((=C(CCCC//////////
# - Sample 303: C/CCCCCCC////////))))))N
# - Sample 304: C=C#CC1]]]333333333333
# - Sample 305: O############################
# - Sample 306: ==========###############
# - Sample 307: /cnnccccccccccccccccc
# - Sample 308: CCCCCCCCCCCCCCCC//////
# - Sample 309: C@]22[CH]2222333333333
# - Sample 310: =C=/////////////////////
# - Sample 311: #CCCC###==#################
# - Sample 312: C/@@H]C@]CCCCCC]CC#######
# - Sample 313: C==C)@@H1CC1]]]]]]]
# - Sample 314: C@1@H]C[@@H1COOOOOOO
# - Sample 315: C[]](OC)))CCCC]////////////
# - Sample 316: C==//////////////////
# - Sample 317: [C@@[@]21C[C@]11Ooo
# - Sample 318: CC@@H]2222222333333333@@@@
# - Sample 319: 1CCCCCCCCCCCCC))))))\
# - Sample 320: C(CCCCCCCCCCCC///////////
# - Sample 321: CCCCCCCCCCCCCCCCCCCCCCC
# - Sample 322: C//==///////////////////
# - Sample 323: Cnnnnnnnnnnnnnnnnnnnnnn
# - Sample 324: Cc1c]ccH)))c1))c))cc))c
# - Sample 325: O=#############################
# - Sample 326: C@@3333233333333333333333@
# - Sample 327: CC@H]CCC111OOOOOOO
# - Sample 328: CCCCCCCCCCCCCCCCCCCCCC
# - Sample 329: C@]1(O)1H11111111111
# - Sample 330: CC(=(((NN))N))]]]]]]]=]
# - Sample 331: CC@H]2C[C@H]1===========
# - Sample 332: CCC=C//C#####)))))))))))))
# - Sample 333: C[@H][C@@H(CCCCC]O)))))))))/)
# - Sample 334: C[CH]CCCC#============
# - Sample 335: CC@](O)[@]C)CC@CH]COCCO[
# - Sample 336: [@H]1[C@@]2C@@H]221111
# - Sample 337: C[]]C][[N]H]))))CCCCCCCCCC))
# - Sample 338: C]NNNN))))C)]]///////
# - Sample 339: CCCCCCCC==1CCCCCCCnnnnnnn
# - Sample 340: CCCCCCCCCCCCCCCC////////
# - Sample 341: C###########################
# - Sample 342: CC[C@H]1OC111111[[[[[[[[[[
# - Sample 343: =C@@2CCCC1[[[nnnnnn[[[[[[[[
# - Sample 344: Ccnncc1111n######
# - Sample 345: CC[N][C[[]]]11111[[[[[[[[[
# - Sample 346: CCCCCC1SSS@@@@@//\\\\\\\
# - Sample 347: 1cccc11]HHHHHHHHHHHH
# - Sample 348: CCC@@()C111111[[[ooo))))
# - Sample 349: OC]11111ooooooooooooooo
# - Sample 350: Cc1cnHccH]]11111HHHHHHHH
# - Sample 351: CCcccccccccccccccccccccc
# - Sample 352: CC][C]C]]CCC]]]]/////
# - Sample 353: CCCCCCCCCCC//////
# - Sample 354: 1CCCCCCCCCCCCCCCCCCCCC
# - Sample 355: CC=CCCCCCC/////////////
# - Sample 356: C=C==///])C))C]]N===
# - Sample 357: CCCCC1111111nnnnnnnnnnnnnnn
# - Sample 358: #####/////////nnnnnnccccccc
# - Sample 359: CC=N))CC============((
# - Sample 360: Ccccccccccccccccccccccc
# - Sample 361: CCCC@]1111@@ooooooooooooooooo
# - Sample 362: CCCC11]O21]]]]n\\\\\\\\\
# - Sample 363: O##=====SSSSSSSSSSS
# - Sample 364: ########################
# - Sample 365: C@@]2N[C@H2@HH32C\\\\\\
# - Sample 366: =CCCCCC===CCCCCCCCCCCCCCCCCCC
# - Sample 367: c((cccccccccccccccc
# - Sample 368: CCCCCCnnnnnnnnnnnnnnn\
# - Sample 369: C[H]()CCH]CC@HHCCC@H]
# - Sample 370: O#########1223#############
# - Sample 371: C@H]1111111nnnooooooo
# - Sample 372: C[@@(O)C@]CCCCCC]OOOOO)
# - Sample 373: C[H]1)CCCCC111)))))))))))
# - Sample 374: C/(==C/////////////////
# - Sample 375: CCCC=CCCCCC()))((11111111
# - Sample 376: C=C1CCCC#=############
# - Sample 377: C[C]]CNNNC)CCC]]]]]]]]]]]
# - Sample 378: Cccccccccccccccccccccc
# - Sample 379: CCC1H]211122@@@@@@@@@@
# - Sample 380: C[]][C]CCH]211111o
# - Sample 381: OnnnSSSSSSSSSSSSSSSSSSSSS
# - Sample 382: C1c[nnn[[[[[[[[[[[[[[[HHHHH
# - Sample 383: CCCCCCCCCCC///#############
# - Sample 384: @
# - Sample 385: c1cccc1cc11111111111
# - Sample 386: O#############################
# - Sample 387: CH2]/==[N]]CCCCCC]N=========
# - Sample 388: C[C][H[C=CCCC]]]]]///////
# - Sample 389: N1@11CC=OOOOOOOOOOOO
# - Sample 390: C/((((((((((((((((((((
# - Sample 391: C=CCCCCCO#C)))))))))))
# - Sample 392: [@@H]2@H]][C@HCCH2CC[[[
# - Sample 393: C1(OCCCCCCCO]//===========
# - Sample 394: CCC1@11111OOssssssssssssssss
# - Sample 395: C[C@]1@C)[CC)[[@@H11o
# - Sample 396: CC1C111111oooooooooo
# - Sample 397: ####@@@@@@@@@@@@@@@@@@@@@@@
# - Sample 398: [C@]][][C]C]]H]CH]H]]]]
# - Sample 399: N[C[CCC11H111111111111
# - Sample 400: #==1====================
# - Sample 401: ccccc1111oooooo\ssssss
# - Sample 402: cccc222222222
# - Sample 403: Cc[nnnc[H[[[HHHHHHHHHH
# - Sample 404: CC=(C=N[N[]]]H]]]]][[[[[
# - Sample 405: CCCC1H1111111111111111
# - Sample 406: [C]1CCOH]1OOOOOOOOOOOOOOOOO
# - Sample 407: [C@@H](OCC[CCCCCCCCCCCOOOO
# - Sample 408: C@@]CC@]2@22COOOOO
# - Sample 409: CC[H]2C[C@@]122233333333
# - Sample 410: C[@H]1CC1H222222222#
# - Sample 411: CC@]]CCCCCCOOO)))/////
# - Sample 412: CCCC1O11nnnnnnnnnnnnn
# - Sample 413: /CCCCC/C//////////
# - Sample 414: 1111ccccccccccccccccc
# - Sample 415: CCccccccccc1111cccccc
# - Sample 416: C1CCC11111SSSSSSSSSSSSS(\
# - Sample 417: C()CC))CCCC//////////////
# - Sample 418: CccH][[[))))))))))[[[H]]]]]
# - Sample 419: ##  nnnnnnnnnnnnnnnnnn
# - Sample 420: CC11222223333333333333
# - Sample 421: ==##########################
# - Sample 422: CC]=NNCCCC11111111111111
# - Sample 423: C@H]2CH]2C[22222222322
# - Sample 424: C[C@H])[[C@]122211111111222
# - Sample 425: 1ccccccccccccccccccccccccc
# - Sample 426:
# - Sample 427: C@]C][CCC)CH]CC[1C
# - Sample 428: cccccccccccccccc
# - Sample 429: C[CH2C[C@@1C[CH3223333333OO
# - Sample 430: /C/]]/))))))))))))))
# - Sample 431: CH]2@H]1C[C@H]2CH2[[@
# - Sample 432: CC(CCCC//////////
# - Sample 433: C@]]1@]O)[@H]CO11OO)
# - Sample 434: [C@]OC@]CCC]1211@]]@@@
# - Sample 435: CC]O)CC]]])C]]]]]]]]]]]
# - Sample 436: C[H]C@H]2[[C@1C@]]11[[[
# - Sample 437: C[@H]1CC@H2[C@H]3222223
# - Sample 438: C2][C][H][H]CCCCCCCC]]]
# - Sample 439: =/C/CC#1#[[/]]]]]]]]]]]]]]]
# - Sample 440: C[[C1C[C@H]1C22221222233333
# - Sample 441: CC()CCCCC11111111111111111
# - Sample 442: C###########nnnnnnnnnnnnnnn
# - Sample 443: [C@H]C)C)CC)))/////////////
# - Sample 444: nnnnn
# - Sample 445: (C)CCCC)CCCCCCC////////
# - Sample 446: cccccccccccccc111111
# - Sample 447: C[C@@][[C@HC[@H]2CCHOOOO
# - Sample 448: cccccccccccccccccccccsssss
# - Sample 449: C][CCCCC]////////
# - Sample 450: C#CCC333333333333
# - Sample 451: [1H11C@H11CC@@H12SSSSS
# - Sample 452: C[H]CC]]CCCCCO]]]]]]///////
# - Sample 453: CCC//C/C1/nnnnnnnnnnnnnn//
# - Sample 454: C@11111oooooooooooooooooo
# - Sample 455: [cccccccccccccccccccccc
# - Sample 456: CCCC@H]222]]]nnnnoooooooooo
# - Sample 457: CcC@]]ccc]]]]]2222222
# - Sample 458: [C@()C[H]H]]CCCCCCCC]C
# - Sample 459: CCCCCCCC=//####=CCCCCC
# - Sample 460: CCCCCC111nnnnnnnnnnnnno
# - Sample 461: CCCCCCCCCCCCCCCCC//////
# - Sample 462: ccccc111111111sssssss
# - Sample 463: CC==CCCC@]CCCCC]NNOOOOOO
# - Sample 464: ON11SSSSSSSSSSSSooooo
# - Sample 465: C[C@@]1C@C1@@C1@]111
# - Sample 466: C1CH]2CC1H12112222211
# - Sample 467: C#@@33333333333333333@@
# - Sample 468: CCCCCCCC==CCCCCCCCCCCCC
# - Sample 469: CCCCCCCC=CCCCCCCCCCCCCC
# - Sample 470: C((C=C))CC///////////////
# - Sample 471: C#CH2222222222333333333
# - Sample 472: ccccccc1111111111===
# - Sample 473: CCCCCCCC///C##==NNNN
# - Sample 474: CC@222C[222322223333333333
# - Sample 475: C((CCCCCC/CCCCCCCCCCCC
# - Sample 476: CC1CC[@][[C111]]]]]]]]]][[
# - Sample 477: n          2222222222222
# - Sample 478: Ccccccccccccccccccccccccc
# - Sample 479: C==C//C//C####))))))))))))]
# - Sample 480: =========================
# - Sample 481: C[C@@]1()CC))))/////////
# - Sample 482: CC[C@@H]([@H]1111111111111
# - Sample 483: C1CCCCCC====CCCCCCCCCC
# - Sample 484: CC]1################
# - Sample 485: C((=O)CCCCC/////////////////
# - Sample 486: #CC@@HHH####             s
# - Sample 487: OCcc11cCCH2NSSSSSSSSSSS
# - Sample 488: C1c())))c]11111111
# - Sample 489: [CH][C@1C[@]1C11@]]11CCC
# - Sample 490: C[@H]1CCH]1C[C@@H]12CSSSSS
# - Sample 491: NO@11#######
# - Sample 492: C1CC1111nnnnnnnnnnnnnoo
# - Sample 493: C/(=//////////////////)))
# - Sample 494: CC]]C=N[CCC1CCO[[[[[
# - Sample 495: CcCcccccccccc11111111cc
# - Sample 496: [@CH[[HCHHH]]]CCCCCC
# - Sample 497: CC12H]]22222222222ssssssss
# - Sample 498: [[cH11CC]1CCCC]22SSSSSSSS
# - Sample 499: CCH](C)[@H11C111111111111

# %%
from rdkit import Chem
from rdkit import RDLogger

# Suppress RDKit warnings (if the model is not well-trained, there will be a lot)
RDLogger.DisableLog('rdApp.warning')
RDLogger.DisableLog('rdApp.error')
RDLogger.DisableLog('rdApp.info')

# Function to canonicalize SMILES; if a string cannot be canonicalized, it is not a valid SMILES
def canonicalize(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        return Chem.MolToSmiles(mol, canonical=True)

# Let's evaluate how many SMILES correspond to valid molecules
valid_smiles = [canonicalize(smiles) for smiles in decoded_smiles if canonicalize(smiles) is not None]
fraction_valid = len(valid_smiles) / len(decoded_smiles)
print(f'Fraction valid SMILES out of {num_samples} samples: {fraction_valid}')

# Let's evaluate how many SMILES correspond to novel molecules
if fraction_valid > 0:  # Don't bother if there are no valid SMILES samples
    reference_smiles = [canonicalize(smiles) for smiles in smiles_strings]  # `smiles_strings` contains all train and test SMILES
    known_smiles = set(valid_smiles) & set(reference_smiles)
    novel_smiles = set(valid_smiles) - set(known_smiles)
    fraction_novel = len(novel_smiles) / len(valid_smiles)
    print(f'Fraction novel molecules out of {len(valid_smiles)} valid samples: {fraction_novel}')
    if fraction_novel > 0:
        print(f"Novel SMILES: {novel_smiles.join(', ')}")
# Out:
# Fraction valid SMILES out of 500 samples: 0.0

# %% [markdown]
# 💡 When checking for novel molecules via SMILES list comparison, ensure that the SMILES strings in both lists are canonicalized before comparing pairs of strings.

# %% [markdown]
# #### Sampling from the latent space

# %%
num_samples = 500

def sample_latent_space(z_mean, z_logvar, num_samples):
    _, latent_dim = z_mean.size()
    random_idc = torch.randperm(z_mean.size(0))[:num_samples]

    # Randomly select `num_samples` random rows of `z_mean`
    z_samples = z_mean[random_idc]

    # Randomly select `num_samples` random rows of `std`
    std = torch.exp(0.5 * z_logvar)
    std_samples = std[random_idc]

    eps = torch.randn(num_samples, latent_dim)

    return z_samples + eps * std_samples

# Generate random latent vectors
latent_samples = sample_latent_space(z_mean, z_logvar, num_samples)

model.eval()
with torch.no_grad():
    generated_samples = model.decode(latent_samples)

# Print the SMILES corresponding to the random latent vectors after decoding
print(f'Random latent vectors decode to:')
generated_smiles = emb_to_smiles(generated_samples, indices_char)
for i, smiles in enumerate(generated_smiles):
    print(f'- Sample {i}: {smiles}')
# Out:
# Random latent vectors decode to:
# - Sample 0: ############
# - Sample 1: [C@H[C@@(O)[@H]C1CC[[
# - Sample 2: CC]]C]]C][H[[[[H]]]H]]]HH
# - Sample 3: C=CCC@CC@22111222222[
# - Sample 4: #CCCCnnnnnnnnnnn
# - Sample 5: O###C#####################
# - Sample 6: [C@H])]]])))))))))))))))
# - Sample 7: C1ccccc1]c1111111111111
# - Sample 8: CCCCC)CCCCCC//////////
# - Sample 9: Cccccccccccccccccc
# - Sample 10: /(@H]()))))))((((((((((
# - Sample 11: C#CCCCCCCCCCC==/###########
# - Sample 12: CCCCCCC===CCCCCCCCCCCCCC
# - Sample 13: C(=N(((((////)////CCCNNNN
# - Sample 14: CCCC###==##############
# - Sample 15: CC@@1CO1OOOOOSSSSSSS[[[[[[
# - Sample 16: c1ccccccccccccc1111ccc
# - Sample 17: CC[C]][CNH[[H][HH][]]]]]]]]1
# - Sample 18: [C@@H]2]3H2CC@2222[[
# - Sample 19: CCCC[@H]#COOOOOOOOOOOO
# - Sample 20: CC=((N///CCCC]N=======
# - Sample 21: CCCCCC)CCCC////CCCCCCC
# - Sample 22: C[C@H]@H]C[22222[3\\\\
# - Sample 23: C1c()c1))))1)))1]]1111111
# - Sample 24: CCC1O]]2nnnnnnnnnnnnnnnnn
# - Sample 25: C@][@H]C[C@][@@H]CCC[
# - Sample 26: CC=C=CCH]]222]333333333333
# - Sample 27: [@H2C@H]CC@]]22CC[####
# - Sample 28: CC]C[C@[C@@H2211111
# - Sample 29: CCC//C//C/C/C/CCCCCCCCCC/////
# - Sample 30: //=////////////
# - Sample 31: ##########################
# - Sample 32: CC=CCC=CCCC)/////////////
# - Sample 33: CC(CCCCC)CCC/////////////
# - Sample 34: =CCCCCC==####CCCCCCCCC
# - Sample 35: CC[C][C[CCC[1111111[[[[[[[[
# - Sample 36: CC(C(=)CCCCCC===========//
# - Sample 37: ccccccccccc111111112222
# - Sample 38: 1C[C@]2[C@@C[[[[[[[[
# - Sample 39: ###############nnnnn
# - Sample 40: @
# - Sample 41: C#CCCCC######CCCCCC#######
# - Sample 42: [C@](OCCC1111OOOO[[[[
# - Sample 43: CCCCCCC##==################
# - Sample 44: CC]]C@]C]@@H[C@@]C[@]]
# - Sample 45: O#########################
# - Sample 46: CCCCCCC========CCCCCCC
# - Sample 47: C1H1111CCCCCCOOSSSSSSSS
# - Sample 48: C(C(CCCCCC////////////////
# - Sample 49: C@]11CC(=)CO)(((((((
# - Sample 50: ///////((((cccccccccccc
# - Sample 51: CC=N))CCC1]]]]]==========11
# - Sample 52: C#nnnnnnnnnnnnnnnnnnnnnn
# - Sample 53: @
# - Sample 54: CCC]1]]]]]]]]]]]]]]]
# - Sample 55: Cccccccc11cccccccccccccccc
# - Sample 56: [HHo
# - Sample 57: OOO=######SSSSSSSSSSSS
# - Sample 58: CC[C]CH[[[][HHHHHH]HHHH]
# - Sample 59: CCCCCCCCC))))))))))]]]]]]
# - Sample 60: C=CC=CCC@H]23333333333333
# - Sample 61: ############################
# - Sample 62: cCc1cccc1111111OOOOOOS
# - Sample 63: CCCCCCO##))))))))))))))))))
# - Sample 64: CCCCCC)CC/CC)))))))))))
# - Sample 65: =C1CCCC=NCC    S
# - Sample 66: Ccccccccccc111111111
# - Sample 67: =CCCCCCCC=//############
# - Sample 68: C((C)CCCCCC//////CCCCCC
# - Sample 69: #########################
# - Sample 70: C#C1CCCC1        sssssss
# - Sample 71: O=SSSSSSSSSSSSSSSSSSSSSSS
# - Sample 72: C(=CCCCCCCC///////////////
# - Sample 73: CCCCCC#O###)))]]]]]]
# - Sample 74: 111=====((((((((((((((((
# - Sample 75: #CCCC12333333333333333333
# - Sample 76: C[[H]CCCCC111111111111
# - Sample 77: #############################
# - Sample 78: CCCCC1=2 sssssss        sssss
# - Sample 79: CC222233[[@@2222222222
# - Sample 80: CCC===//////////////////////
# - Sample 81: @H()CCCCCCCC11OOOOOOOO[
# - Sample 82: C[@@H1C@H]1[C@H]122C1OOOOO
# - Sample 83:
# - Sample 84: (C)CCCC==CCCCCCCCC=nnnn
# - Sample 85: CC[CH]([@@[[C)CC@H]1111111
# - Sample 86: CC(=)C@nnnnn========
# - Sample 87: C1ccccccccccccccccccc
# - Sample 88: C[C@][CH(C[HH]CO1CCC[[
# - Sample 89: CCCCC1111@@@@@@@@@@@@@@
# - Sample 90: CC[C]]CH][H]CH]CCCCC]]]CCC]]]]
# - Sample 91: C1CC111111111111111111111
# - Sample 92: C@@][@]C@H]1[22H]22C
# - Sample 93: cccccc11111ccHHHHHH
# - Sample 94: @@H]][C@H]CC)@@HC[@H]CCC
# - Sample 95: [C@H][C@@H]O)@@H]OOO))))))
# - Sample 96: C[C][CHC)CO]]]]]]///////
# - Sample 97: ###
# - Sample 98: [C@][C@H]C[C@@H]CCHH]3[[
# - Sample 99: #######################S
# - Sample 100: CC@H](OC])CCCC))))///
# - Sample 101: CCCCC[C]][N][[H][]][]]HH]]][[
# - Sample 102: ccccccc22222222222222
# - Sample 103: CC@]1O))C)////////////
# - Sample 104: @         @@@@@@@@@@@@@@@@@
# - Sample 105: CC]]C=N=[N[N][[]]CCCCC[[
# - Sample 106: [H][[C]]]]]]]]]]]]]
# - Sample 107: O#####################
# - Sample 108: C=//////))))))))))))))))
# - Sample 109: CC(=((((((N)CCCC=========
# - Sample 110: C[@1(CC11]11))))))))
# - Sample 111: C[][CCH]]11]]][[[[[
# - Sample 112: C[C@CH[@@]][@]11O111111
# - Sample 113: CCCCC))CC/////////
# - Sample 114: ccccccccccccccc)
# - Sample 115: C/(=/=)))///////////
# - Sample 116: 1cccccccccc11111111111111111
# - Sample 117: C[2]/N=//]///))]]]]]]])//
# - Sample 118: C(=//(]))]]]]]]]]]]]]]]
# - Sample 119: CC(CCC(=))CCC////NNNNNN
# - Sample 120: ###
# - Sample 121: HHo[[[[[[[[[[[[[[
# - Sample 122: =CCCCC#///############
# - Sample 123: /=CCC=C))CC///////////
# - Sample 124: Ccnc1####
# - Sample 125: CcC@@H]C@]]CC@2223333[[[[[
# - Sample 126: C[C[H]CCCCCCCCCCCCOOONNNN[[[[[
# - Sample 127: CCC@H1O11H1[[[[[[[33333333
# - Sample 128: CN][HH11211]22221111111111
# - Sample 129: C(CCCCCCC///////////////C
# - Sample 130: C@@C[@@]C[2222[[[[[[[[
# - Sample 131: CCH]222233333333333333333
# - Sample 132: CC(CCCC)CCCC/////////////
# - Sample 133: C/C=C//[N]H]/[HH]]]]]]]]]]
# - Sample 134: CCC@H1[@H]2C
# - Sample 135: c@[CHCC[222[[[[[[[[
# - Sample 136: #############################
# - Sample 137: C/(=CCC)/C//////////
# - Sample 138: C=CCCCCC==###########CCC
# - Sample 139: CC=C/@H]1CC12]]]]]]/////
# - Sample 140: CC=CCCCCCCCC///////////
# - Sample 141: #CCCCCCC#=############
# - Sample 142: C[@]1C@C[@@H2C@H]2C[H
# - Sample 143: =((())CCCCC===========
# - Sample 144: CCCC]]3333333333
# - Sample 145: N111C@HCCC#@@HNNSSSSSSSSSS
# - Sample 146: C##@@@@@@@@@@@@@@@@@@@@@
# - Sample 147: #C############22##########2
# - Sample 148: Ccc)cc11==========oooooo
# - Sample 149: [@]1[C2C@H]1OO11OOOOOO
# - Sample 150: CC==((((((//)))/CC]]]]]
# - Sample 151: CC[C]C@HO1@112222222222
# - Sample 152: C[C@]1[@@(O)[1]OO11NNNNNNN
# - Sample 153: ccc
# - Sample 154: C1cccccccccc11111111111
# - Sample 155: CC())C)CCCCC/////////////////
# - Sample 156: [C]][N][][[C]]CCCCCCCCCCNN
# - Sample 157: #####nnnnnnnn############
# - Sample 158: [HHooooooooooooooooooooooo
# - Sample 159: CC[CHCHC][[][CH[[]H]HHHH
# - Sample 160: C[C@OCC11)]]SSSSSSSSS
# - Sample 161: =C/CC########################
# - Sample 162: C[CCCC1111]](((((((((()))
# - Sample 163: C[@[H]2CO)C@]OOOCNOOOOO
# - Sample 164: C=CC/##############
# - Sample 165: =11C1111cc1cccccccccccccccc
# - Sample 166: C1CCCCCCCC=CCCCCCCCCCCCCCCC
# - Sample 167: /C===///C////////////
# - Sample 168: C[C@H]C@@H2@H]C)[@]22Oo
# - Sample 169: OCCC1###s
# - Sample 170: CC@HC[C@H2233333333333
# - Sample 171: C[CC[N][HHH[HH]HHHH
# - Sample 172: CCCCC/CCCCCC///////////
# - Sample 173: CC@H]2[[cc22[c22]222]22222H
# - Sample 174: C@]22CC@H]2222333333333
# - Sample 175: 122[[[[[[ccccccccccccccc[[
# - Sample 176: CCCCCCCCCCCCCCCCCC
# - Sample 177: C[C@]C(()C111111111[[[[[[
# - Sample 178: OOCC####SSS
# - Sample 179: 1CCCC1111]]]]]]]][[[[[
# - Sample 180: C1CCN1C11111111[[[[[[[[[
# - Sample 181: Cc1cccccccccccccccccccc
# - Sample 182: CCC@H1O1@@]]]]]]]]][[[[oo
# - Sample 183: =CCCCCCC=#############
# - Sample 184: N@1111O@@@ooooooooooooooo
# - Sample 185: #CCC=CCC22222222222
# - Sample 186: C=CCCC#==###############
# - Sample 187: N=#####///////////////////
# - Sample 188: C[]]/NNNCCCCCCOC]/////////
# - Sample 189: ###########################
# - Sample 190: []H[CHHCCC]]]CCCC[[[[
# - Sample 191: CC@@]C@@H])C@H]C[C@HCCCCCC
# - Sample 192: C[C]N)CC=)CO)///////////
# - Sample 193: [@C]C]C]C]C]]CC]]]]]
# - Sample 194: Cnnnn11nnnnnn###############
# - Sample 195:
# - Sample 196: C[@@1(OCCCCC1]]][[[[[[[
# - Sample 197: CNH]CHCCC)C2////////////////
# - Sample 198: cccccc
# - Sample 199: =CC11111)33\\\\\\\\\
# - Sample 200: CC())CCCCCC////////CCCCCCC
# - Sample 201: CC@1CCC11@]122((((
# - Sample 202: #CC##################
# - Sample 203: OCC1@HH333333333333333333
# - Sample 204: C[@H)CHH]]]]]]]]]]]]]]/
# - Sample 205: C=[NNCC]1111[[[[[[
# - Sample 206: ===########################
# - Sample 207: Cc1ccccc111111111111ccc
# - Sample 208: CCCCCCCCC////////////C
# - Sample 209: CCCCCCCCC/////////////
# - Sample 210: CC@CCC1111111111[[[[[
# - Sample 211: OCCC#################
# - Sample 212: [C@]cccccccccccccccccccc
# - Sample 213: CCC=(())))CC11)[[[[N]]]]
# - Sample 214: CC=CC(()[[H]C)]]]]]]
# - Sample 215: CCCCCCCCCCC##CCCCCCCCCCCC)
# - Sample 216: CC(()C)CCCCCCCCCCCCCCCC
# - Sample 217: C[1CCCC@H1(O)C)////////////
# - Sample 218: ###@@
# - Sample 219: cccc11111111111OOOOOOOOOOOO
# - Sample 220: CC2Hccc11222222222222
# - Sample 221: /==///////////////////////
# - Sample 222: CCC==[C]][H]]HH]]]]]]]]]]
# - Sample 223: Ccccccccccccccccccccccc
# - Sample 224: ##
# - Sample 225: C=CCCCCccccccccccccc11111
# - Sample 226: C[C@H1OO#@nnnnnnnnnnnnnn
# - Sample 227: ccccccccccccccccccccSSSSS
# - Sample 228: cccc1111cc2222222222222
# - Sample 229: [C@CCCC]1O1111111122222222
# - Sample 230: @@H]111111nn[[[[[[[
# - Sample 231: CC/[H[[][H]HH]]]]]]]]]]](((
# - Sample 232: ]][]]CCCCCCCCCO]]
# - Sample 233: C[H]1=O11]]]]]]]]]OOOOO
# - Sample 234: C==CCCCCCCC//////////
# - Sample 235: CCC][N][[H][[H]]CCCCCCCC]
# - Sample 236: 1C@]CC@@]C[@@11@]]22CC
# - Sample 237: H
# - Sample 238: C=[[CH]2[C@H][CH]C[C]]22C
# - Sample 239: C[C@@H]())@](C)C@]HO)CCCCCC
# - Sample 240: C=C1CCCC====#############
# - Sample 241: C[C](CC]C)111]OOOOOO
# - Sample 242: C1CC=C==CCCCCCnnnnnnn
# - Sample 243: =c1c[nHcc11111111HHHHHHHHH
# - Sample 244: CCCCCC=#NCC
# - Sample 245: #########################
# - Sample 246: =CCCCCC1 CCCCCCCCCCCCC
# - Sample 247: CC]CCC11]]SSS)))))))))))
# - Sample 248: @
# - Sample 249: Cc11cccccccc111111111HHHHHHHHH
# - Sample 250: #######################
# - Sample 251: [C@H[()[C@H](O)))))))
# - Sample 252: CC]====/NNNNNNNNN//)CCC
# - Sample 253: CC]1(CC@H1NN=============
# - Sample 254: CCCc1ccccc1cccc@@@@@@@
# - Sample 255: C[C@]1()CC/////////////
# - Sample 256: CCCCCCCCN=CCCCnnnnnnnnnnn1
# - Sample 257: C[@]1C@H]2C)[C@H]11[\\\
# - Sample 258: 1@H]C[C@H]12221113333333
# - Sample 259: CCCCCCCCC////////////
# - Sample 260: C=C1CCCCCC1333[]]]]]]]]]
# - Sample 261: 1[C@[@@]2[H]CC@H]1C
# - Sample 262: CCH=NCH]1222222===1111
# - Sample 263: c1ccc(ccccc)c1c1111111
# - Sample 264: C@@H(C)CCCC111OOOO[))))))
# - Sample 265: OO111=11sssssssssssssss
# - Sample 266: CC=CC[CH2C@H]12112]][[[[333
# - Sample 267: c1cccc111]]HHHHHHHHHHHH
# - Sample 268: C#C#####2##############
# - Sample 269: 1ccccccc[[[[[[[[[[[[[[[[
# - Sample 270: CCCCCC=
# - Sample 271: C[]N][HH]/CC]CCCCCCC]]
# - Sample 272: CC=C/CCCC////CCCCCCC))
# - Sample 273: cc[cHHHH]]111111222222222
# - Sample 274: CCCCCC=/CCCCCCCCCCCC
# - Sample 275: C#ccnnnnnn1nnnnnnnnnnn####
# - Sample 276: C(OCCC]222==================
# - Sample 277: @H
# - Sample 278: #CCH]1C##################
# - Sample 279:
# - Sample 280: CC1CCCC@H]O1@@1///OOOO///
# - Sample 281: #######################
# - Sample 282: O##CC######################
# - Sample 283: CC(CCC==CC///////////////
# - Sample 284: CC[C]CN=[][CH]CCCCCCCC[
# - Sample 285: C(CC)/CC////////////////
# - Sample 286: CCCCCCCC//////////////
# - Sample 287: [CC][C]CCOOO]]///////
# - Sample 288: ][CH]CCCCCCCCCCOOO]]]]]
# - Sample 289: ccccccccc111ccccccccccc
# - Sample 290: CC1111]]]]]]]=======
# - Sample 291: CCCCCCC====CC#########
# - Sample 292: ///C//C/////////////
# - Sample 293: C[H]=[NNNNCCCCCCCNNN=
# - Sample 294: Ccc111O)))))))))))))))
# - Sample 295: 1cccccccccc[)c[HH]]11111111
# - Sample 296: #CCCH1O##Cnnnnnnnnnnn
# - Sample 297: @
# - Sample 298: OOCCC111111111111
# - Sample 299: C#nnnnnnnnnnnnnnnnnnnnnnnnn
# - Sample 300: CCC@H]2C)@@H]CC@@]]CC]]2
# - Sample 301: [cCCC@H1CCCSSSSSSSSSSS
# - Sample 302: CN]CC))))//////////////
# - Sample 303: ccccccccccccc1111111111111
# - Sample 304: [C]cccccccccccccccccccc
# - Sample 305: CCCCCCC//////////CCCCCCC
# - Sample 306: O###########################
# - Sample 307: C[H][C][H[[[][]]H]]HH]
# - Sample 308: CC=CCCC111111111111111
# - Sample 309: CCC=CCCCCC)))))))))NNNN
# - Sample 310: CCCCC/C/CCCC///////
# - Sample 311: CCC1C1111111111111111
# - Sample 312: #C###################
# - Sample 313: #####
# - Sample 314: C@2C@H222@H   SSSSSS
# - Sample 315: CC)CCCCC////////C
# - Sample 316: [C]C][C][HHHHHHHHHHH]]
# - Sample 317: C=CCCC=################
# - Sample 318: C/C===///////////////////////
# - Sample 319: CC@]11[C@@H]H]12222333
# - Sample 320: Cccccccccccccc[[[[1111
# - Sample 321: CCCCCCC///////////CCCC
# - Sample 322: CH]())())cccccccccc
# - Sample 323: Cc1ccccccccccc11111111111111
# - Sample 324: nnnnn
# - Sample 325: C1CCCCC11111111111111111
# - Sample 326: =##////////////////////
# - Sample 327: H][NC=CCC22=====/////
# - Sample 328: Cccccccccccccccccccccccc
# - Sample 329: CCC)[[[[111][[[[[[[
# - Sample 330: C=CCC((/)))))//NNNNNNNNNNNN
# - Sample 331: C]][C[CH[C]]][C@][CC@
# - Sample 332: O=##############################
# - Sample 333: CC][CCCC11111OO)))))))
# - Sample 334: C@H[@@H](N)@H]]]]\\\\\\
# - Sample 335: =CcCcCccccccccc111111111
# - Sample 336: C1C[C]2OC@]1C11@H]23333333
# - Sample 337: #CCCC1O]]]]223333333ssss
# - Sample 338: ccccccccccccccccccccc
# - Sample 339: CCC][C]C1111121[[[[[[[[
# - Sample 340: C/((////CCC/////////////////
# - Sample 341: OCCCCC################
# - Sample 342: C@H([C@H]([HCC\\\\\\
# - Sample 343: C//))//)))))(((((((((
# - Sample 344: C1[C@H]@HH][@@]3[[C@]22[[
# - Sample 345: ccccccccccccc111ccccccccc
# - Sample 346: CCCCCCCCCCCCCCCCCCCCCCCCCC
# - Sample 347: CCCCCCCCCCCC//////////////
# - Sample 348: CC@O111]]]] ooooooo
# - Sample 349: []NCC)/////////////
# - Sample 350: CC=CCCOCnnnnnnnnnnnnnnnnnn
# - Sample 351: CCCCC/C/CCC///////////////
# - Sample 352: C=CCCCCCCCCCC############
# - Sample 353: C(C()[@H](COC=========
# - Sample 354: C@@H22C2333333333333
# - Sample 355: C[C@@[]O]]]]2nnnnnn=====
# - Sample 356: CCCCCC=/////////////
# - Sample 357: CC@@@H)))))))))))))))
# - Sample 358: C=(NCC]22======11
# - Sample 359: C#CCC####=##################
# - Sample 360: CH]2[C@HH]C[@H]CCC@]1CCC@H
# - Sample 361: 1CCCCC==CCCCCCCC
# - Sample 362: [@]OHC]C]]]]]]]]]]]
# - Sample 363: C(((N)CCC==============11
# - Sample 364: ccc22222222222222222222
# - Sample 365: C#CCCCCCCC###################
# - Sample 366: ##C#####################
# - Sample 367: CCCCC11S@@@@\\\\\\
# - Sample 368: CCCCCCCCCCC===CCCCCCCCCCCCCCC
# - Sample 369: C##C###################
# - Sample 370: @H]()C)))))))////////////
# - Sample 371: CCCCCCCCCCCCCCCCCCCCC////
# - Sample 372: 1cccn[[[[[[[[[HHHHHH]]
# - Sample 373: ((=N[))C]]]]]]]]]//
# - Sample 374: C1cH[HHHHHH]]111111H
# - Sample 375: CC]1C@](C)C]O11]]SSS
# - Sample 376: Cccccc111111111111111111
# - Sample 377: C[C@1C1C1C111]]]]11)))))
# - Sample 378: @
# - Sample 379: CN][=CCCC11]]]111111111
# - Sample 380: [C@1cccccccccccccccccccc
# - Sample 381: CCC@]122@333333333333333
# - Sample 382: CC[@H]O11soooooooooooooooo
# - Sample 383: Ccccccccc1111cccccc
# - Sample 384: 1ccc(c1))c11]11111111
# - Sample 385: C[HH]=[N/N[N[]))CCCC]]]]
# - Sample 386: C1CC=C==CCCCCCCC
# - Sample 387: CC[]]CH]N=H[H][H]]]]]]]]]]]]
# - Sample 388: /(==(=/CC//////////
# - Sample 389: (C)[@2[C@@]C[C@2222[[333
# - Sample 390: ((=(=)CCCC///////CCCCNNNNN
# - Sample 391: C[@H1[C@H]2C@]1C1C11222
# - Sample 392: CCCCC1C1111111111111111111
# - Sample 393: C/((=//////////////////////
# - Sample 394: CCCCCCN1[[[[[]]]]]]]]]][
# - Sample 395: C#CCCCCC#################
# - Sample 396: CC@H]1@H]2COC1@211111OOO
# - Sample 397: [C@H]CCC111111]]2222222222
# - Sample 398: CC@H]1[@H]C@@C[C@]22[[
# - Sample 399: ######################
# - Sample 400: CCC=C/CCN)nnnnnnnnnnnnnnnn
# - Sample 401: C(()CC1nnnnnnnnnnn111111
# - Sample 402: C[CH]@H](CCC1C]12)(((((
# - Sample 403: =C1CCCCCCC
# - Sample 404: CCC@H]1C]2CC@@222    SSS
# - Sample 405: C=N)CCCCCC12===============
# - Sample 406: C/==////////////////
# - Sample 407: []/==NH/CCCCCCCCCN==[[
# - Sample 408: C=C1CCCCC1NCCCCCCCCCCCCCCC\
# - Sample 409: C=CCCCCC#####
# - Sample 410: CCC=CCCCCCCCCCCCCCCCCCCCCC
# - Sample 411: C@H]11111111111ooooooo
# - Sample 412: CC]=(NNCCCCCCC]===========
# - Sample 413: CCcccccccccccccc11111
# - Sample 414: OCCC##2      ###########
# - Sample 415: Cnnnnnnnnnnnnnnnnnnnnnnnnnnn
# - Sample 416: CCC1H]11O1@oooooooooooooo
# - Sample 417: C1[C@H]O11]222111111111
# - Sample 418: C1[@H]@H]CCC@@]1111111
# - Sample 419: C[@1CCH]()CC@1OO11]]]]S
# - Sample 420: ccccccccccccccccccc
# - Sample 421: CCCC)CCCCCC///////////
# - Sample 422: CC][C=H]]]11]22===11111
# - Sample 423: ccccc111111cccccccccccc
# - Sample 424: CC()CCNN=======))))))))
# - Sample 425: #CCCC122222333333333333333
# - Sample 426: #CC@H]2222233333333333333
# - Sample 427: #
# - Sample 428: C#CC######################
# - Sample 429: C1C@]2CCC[C@H1222]nn\\\
# - Sample 430: C#CCCC112               s
# - Sample 431: CCCCCCCCCCC/////////////
# - Sample 432: Ccccc11111111111111111]
# - Sample 433: Cc1ccccccccc111111111
# - Sample 434: CCCCCCC///////////////CCC
# - Sample 435: C((=(=CCCCC//////////////
# - Sample 436: Cc11ccccccccccccccccccccc111
# - Sample 437: C1@H]2[[CH]1[C@@H2CCC3CCC
# - Sample 438: CC@]1CCC@]Ooooooooooooo
# - Sample 439: CCCCCCC11CCNNNNOO/////
# - Sample 440: O@@]1=oooooooonnnnnnnnn
# - Sample 441: CC@H]1)[@H1222211222222
# - Sample 442: OO###########                 S
# - Sample 443: cccccccccccccsssssssssss
# - Sample 444: [@]1cc[[]][[[]]]]]]]]]
# - Sample 445: CC=CCCC/CCCCCCCCCCCCCC
# - Sample 446: C#CCC###=################
# - Sample 447: C11c1CC@C@H2CSSSSSSSS
# - Sample 448: CNH][CCCC)))/////////////
# - Sample 449: CC1CCC11nnnnnnnnnnnn
# - Sample 450: CCCC((=O)CNC))))))))]]]]
# - Sample 451: C==NNCCCCC111]]11111111111111
# - Sample 452: CCC1ccccn11111111111nnnnn
# - Sample 453: CC(CCCCCCCCCC///////////////
# - Sample 454: (()CCCC111111111111111111
# - Sample 455: C222[[[[cccc[[[[[[[[
# - Sample 456: CC()CCC)CCCC//////CNNN===
# - Sample 457: C1CCCCCCCC=======CCCCCCCC
# - Sample 458: Cc(cccc111111ooooooooooooo
# - Sample 459: C(C)CCC=CCCC////////////
# - Sample 460: CC(=CCC)CCC/////////////
# - Sample 461: CC(CCCCCCCC[[[]][[[[[[[[[
# - Sample 462: O######@@                #
# - Sample 463: [C][CCCCCC1111[[[[[[[[[[
# - Sample 464: CCCCCCCCCCCCCC===/////////
# - Sample 465: CC=/[[N]]]]HH]1]]]]]]
# - Sample 466: CCC@]2C[C@@H22223333333
# - Sample 467: [[@11@@1
# - Sample 468: CCN=H122222211111111
# - Sample 469: C(CCCCCCC/CCCCCCCCCCCCCCCCC
# - Sample 470: 1CCCCCCC===CCCCCCCCCCC
# - Sample 471: N[11CCCH]1OSSSSSSSNNNNNNN
# - Sample 472: 1CCC1111[[[[[[[[[[[[[
# - Sample 473: C=CC#C##################
# - Sample 474: [C]]C]][NH][][H[HH]]]]C
# - Sample 475: [HH]]NH])N]CC]]]]]]]]
# - Sample 476: C(/)CCC]]///////////
# - Sample 477: SSSSSSSSSSSSSSSSSSSSS
# - Sample 478: CC[C]CCC]11111]]]]1111111111
# - Sample 479: C[C@H]CC@H2C@]]3C[C@
# - Sample 480: N(=((NNNNC)H]]]]]======
# - Sample 481: ===================
# - Sample 482: #####=====nnnnnnnn111
# - Sample 483: CC[@H])C@H]]22CCCCCCCCCC
# - Sample 484: [@H]11CCC11111111]]]]22222
# - Sample 485: /((//////////////
# - Sample 486: C[C@@]1C@]CCC1@]1C1CC
# - Sample 487: CC]N((1111111111111111))
# - Sample 488: C[C][C@@H(C)C]C111\\\
# - Sample 489: Cccccccc111111111111
# - Sample 490: CCCCCCCCCCCCCCCCC//////
# - Sample 491: CC[C@H]1111OOOOO########
# - Sample 492: CC=CCCCCCCCCC////////
# - Sample 493: CCC(C)CC=ONNnnnnnnnnnnnnn
# - Sample 494: CC=11Onnnnnnnnn
# - Sample 495: C[CH]1C@H](O)CC]OO)))(((\//
# - Sample 496: 1C[@H]11@H12222nnnnnnnn
# - Sample 497: ####////////////////
# - Sample 498: OCCC##    ###############
# - Sample 499: CCH][]CHC]]]]]]CC]]]][[[

# %%
# Let's evaluate how many SMILES correspond to valid molecules
valid_smiles = [canonicalize(smiles) for smiles in generated_smiles if canonicalize(smiles) is not None]
fraction_valid = len(valid_smiles) / len(generated_smiles)
print(f'Fraction valid SMILES out of {num_samples} samples: {fraction_valid}')

# Let's evaluate how many SMILES correspond to novel molecules
if fraction_valid > 0:  # Don't bother if there are no valid SMILES samples
    reference_smiles = [canonicalize(smiles) for smiles in smiles_strings]  # `smiles_strings` contains all train and test SMILES
    known_smiles = set(valid_smiles) & set(reference_smiles)
    novel_smiles = set(valid_smiles) - set(known_smiles)
    fraction_novel = len(novel_smiles) / len(valid_smiles)
    print(f'Fraction novel molecules out of {len(valid_smiles)} valid samples: {fraction_novel}')
    if fraction_novel > 0:
        print(f"Novel SMILES: {', '.join(list(novel_smiles))}")
# Out:
# Fraction valid SMILES out of 500 samples: 0.018
# Fraction novel molecules out of 9 valid samples: 0.7777777777777778
# Novel SMILES: , CC=CCCCCCCCCCCCCCCCCC, CCC=CCCCCCCCCCCCCCCCCCCCCC, CCCCCCCCCCCCCCCCCC, SSSSSSSSSSSSSSSSSSSSS, CCCCCCCCCCCCCCCCCCCCCCCCCC, O=[SH]SSSSSSSSSSSSSSSSSSSSSS

# %% [markdown]
# 💡 Sample from the prior! For molecular generation, it should be clear that it is better to sample intelligently from the latent space of the model than to generate completely random latent vectors; you will sample more valid SMILES. Avoid arbitrary or uniform sampling unless that is specifically intended.
